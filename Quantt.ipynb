# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from pathlib import Path

# %matplotlib inline

# %%
# Reading whale returns
csv_path = Path("./Resources/whale_returns.csv")
whale_returns = pd.read_csv(csv_path, parse_dates=True, index_col="Date", infer_datetime_format=True)
whale_returns.sort_index(inplace=True)
whale_returns.head()
# Out:
# /var/folders/xm/vgvg7x2542z4x7bz20hpz4_r0000gn/T/ipykernel_60230/2641781255.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   whale_returns = pd.read_csv(csv_path, parse_dates=True, index_col="Date", infer_datetime_format=True)
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
nulls = whale_returns.isnull().sum()
nulls
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns.dropna(inplace=True)
whale_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1059 rows x 4 columns]

# %%
# Reading algorithmic returns
csv_path = Path("./Resources/algo_returns.csv")
algo_returns = pd.read_csv(csv_path, parse_dates=True, index_col="Date", infer_datetime_format=True)
algo_returns.sort_index(inplace=True)
algo_returns.head()
# Out:
# /var/folders/xm/vgvg7x2542z4x7bz20hpz4_r0000gn/T/ipykernel_60230/3384202392.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   algo_returns = pd.read_csv(csv_path, parse_dates=True, index_col="Date", infer_datetime_format=True)
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns.dropna(inplace=True)
algo_returns
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %%
# Reading S&P 500 Closing Prices
csv_path = Path("./Resources/sp500_history.csv")
sp500_history = pd.read_csv(csv_path, parse_dates=True, index_col="Date", infer_datetime_format=True)
sp500_history.sort_index(inplace=True)
sp500_history.head()
# Out:
# /var/folders/xm/vgvg7x2542z4x7bz20hpz4_r0000gn/T/ipykernel_60230/1079029474.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sp500_history = pd.read_csv(csv_path, parse_dates=True, index_col="Date", infer_datetime_format=True)
# /var/folders/xm/vgvg7x2542z4x7bz20hpz4_r0000gn/T/ipykernel_60230/1079029474.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500_history = pd.read_csv(csv_path, parse_dates=True, index_col="Date", infer_datetime_format=True)
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
if 'Close' in sp500_history.columns:
    # Remove the dollar sign and convert the column to float
    sp500_history['Close'] = sp500_history['Close'].str.replace('$', '').astype(float)

# %%
# Calculate Daily Returns
sp500_returns = sp500_history.pct_change()
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
sp500_returns = sp500_returns.dropna()

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_returns.rename(columns={'Close': 'SP500 Close'}, inplace=True)
sp500_returns
# Out:
#             SP500 Close
# Date
# 2012-10-02     0.000872
# 2012-10-03     0.003624
# 2012-10-04     0.007174
# 2012-10-05    -0.000322
# 2012-10-08    -0.003457
# ...                 ...
# 2019-04-16     0.000509
# 2019-04-17    -0.002274
# 2019-04-18     0.001579
# 2019-04-22     0.001012
# 2019-04-23     0.008841
#
# [1648 rows x 1 columns]

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
column_appended_data = pd.concat([whale_returns, algo_returns, sp500_returns], axis="columns", join="inner")
column_appended_data
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# ...                                 ...                     ...       ...
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2  SP500 Close
# Date
# 2015-03-03 -0.000949    -0.004539
# 2015-03-04  0.002416    -0.004389
# 2015-03-05  0.004323     0.001196
# 2015-03-06 -0.011460    -0.014174
# 2015-03-09  0.001303     0.003944
# ...              ...          ...
# 2019-04-16  0.002899     0.000509
# 2019-04-17 -0.005228    -0.002274
# 2019-04-18 -0.001229     0.001579
# 2019-04-22 -0.001936     0.001012
# 2019-04-23  0.009622     0.008841
#
# [1043 rows x 7 columns]

# %%
#Conduct Quantitative Analysis

# %%
# Plot daily returns of all portfolios
daily_returns = column_appended_data.pct_change()
daily_returns.plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + daily_returns).cumprod() - 1
cumulative_returns.plot(figsize=(10,5), title="Cumulative Returns over the Last 4 Years")
# Out:
# /Users/june/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:57: RuntimeWarning: invalid value encountered in accumulate
#   return bound(*args, **kwds)
# <Axes: title={'center': 'Cumulative Returns over the Last 4 Years'}, xlabel='Date'>

# %%
# Box plot to visually show risk
column_appended_data.plot(kind='box', figsize=(12, 8), title="Portfolio Risk")
# Out:
# <Axes: title={'center': 'Portfolio Risk'}>

# %%
# Calculate the daily standard deviations of all portfolios
daily_std_dev = column_appended_data.std()
daily_std_dev
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# SP500 Close                    0.008554
# dtype: float64

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_std_dev = daily_std_dev['SP500 Close']
# Determine which portfolios are riskier than the S&P 500
riskier_than_sp500 = daily_std_dev[daily_std_dev > sp500_std_dev]

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
rolling_std_21 = column_appended_data.rolling(window=27).std()
# Plot the rolling standard deviation
rolling_std_21.plot(figsize=(12,6), title="21-Day Rolling Standard Deviation")
# Out:
# <Axes: title={'center': '21-Day Rolling Standard Deviation'}, xlabel='Date'>

# %%
# Calculate the correlation
import seaborn as sns
correlation_matrix = column_appended_data.corr()

# Display the correlation matrix
print("Correlation Matrix:")
sns.heatmap(correlation_matrix)
# Out:
# Correlation Matrix:
# <Axes: >

# %%
# Calculate covariance of a single portfolio
covariance = whale_returns.rolling(window=60).cov(sp500_history)

# Calculate variance of S&P 500
variance = sp500_history.var()
# Computing beta
beta = covariance / variance
# Plot beta trend
beta.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Use `ewm` to calculate the rolling window
ewm = column_appended_data.rolling(window=7).std().plot()

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (column_appended_data.mean() / column_appended_data.std()) * np.sqrt(252)

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar', title="Annualized Sharpe Ratios")
# Out:
# <Axes: title={'center': 'Annualized Sharpe Ratios'}>

# %%
# Reading data from 1st stock
csv_path = Path("./Resources/amzn_historcial.csv")
amzn_history = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
amzn_history.sort_index(inplace=True)
amzn_history.index = amzn_history.index.date
amzn_history.head()
# Out:
# /var/folders/xm/vgvg7x2542z4x7bz20hpz4_r0000gn/T/ipykernel_60230/2102488651.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   amzn_history = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
#             Close
# 2018-05-01  79.11
# 2018-05-02  78.48
# 2018-05-03  78.60
# 2018-05-04  79.05
# 2018-05-07  80.01

# %%
# Reading data from 2nd stock
csv_path = Path("./Resources/blk_historcial.csv")
blk_history = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
blk_history.sort_index(inplace=True)
blk_history.index = blk_history.index.date
blk_history.head()
# Out:
# /var/folders/xm/vgvg7x2542z4x7bz20hpz4_r0000gn/T/ipykernel_60230/289740853.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   blk_history = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
#              Close
# 2018-05-01  517.97
# 2018-05-02  514.79
# 2018-05-03  511.67
# 2018-05-04  520.40
# 2018-05-07  523.60

# %%
# Reading data from 3rd stock
csv_path = Path("./Resources/meta_historcial.csv")
meta_history = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
meta_history.sort_index(inplace=True)
meta_history.index = meta_history.index.date
meta_history.head()
# Out:
# /var/folders/xm/vgvg7x2542z4x7bz20hpz4_r0000gn/T/ipykernel_60230/3784022028.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   meta_history = pd.read_csv(csv_path, index_col='Date', parse_dates=True, infer_datetime_format=True)
#              Close
# 2018-05-01  173.86
# 2018-05-02  176.07
# 2018-05-03  174.02
# 2018-05-04  176.61
# 2018-05-07  177.97

# %%
# Combine all stocks in a single DataFrame
combined_df = pd.concat([meta_history, blk_history,], axis='columns', join='inner')
combined_df.head()
# Out:
#              Close   Close
# 2018-05-01  173.86  517.97
# 2018-05-02  176.07  514.79
# 2018-05-03  174.02  511.67
# 2018-05-04  176.61  520.40
# 2018-05-07  177.97  523.60

# %%
# Reset Date index
combined_df.reset_index(inplace=True)

# %%
# Reorganize portfolio data by having a column per symbol
combined_df = pd.concat([amzn_history['Close'].rename('AMZN'), blk_history['Close'].rename('BLK'), meta_history['Close'].rename('META')], axis=1)
combined_df.head()
# Out:
#              AMZN     BLK    META
# 2018-05-01  79.11  517.97  173.86
# 2018-05-02  78.48  514.79  176.07
# 2018-05-03  78.60  511.67  174.02
# 2018-05-04  79.05  520.40  176.61
# 2018-05-07  80.01  523.60  177.97

# %%
# Calculate daily returns
myport = combined_df.pct_change()
# Drop NAs
myport.dropna(inplace=True)
# Display sample data
print(myport.head())
# Out:
#                 AMZN       BLK      META
# 2018-05-02 -0.007964 -0.006139  0.012711
# 2018-05-03  0.001529 -0.006061 -0.011643
# 2018-05-04  0.005725  0.017062  0.014883
# 2018-05-07  0.012144  0.006149  0.007701
# 2018-05-08 -0.004874 -0.007009  0.005338

# %%
# Set weights
weights = [1/3, 1/3, 1/3]
# Calculate portfolio return
weighted_returns = myport.multiply(weights).sum(axis=1)

# Display sample data
weighted_returns.head()
# Out:
# 2018-05-02   -0.000464
# 2018-05-03   -0.005392
# 2018-05-04    0.012557
# 2018-05-07    0.008665
# 2018-05-08   -0.002182
# dtype: float64

# %%
# Join your returns DataFrame to the original returns DataFrame
column_appended_data = column_appended_data.join(myport,how='inner')

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
column_appended_data.dropna(inplace=True)
column_appended_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-02                  -0.007923           -0.011448
# 2018-05-03                  -0.005584           -0.010606
# 2018-05-04                   0.013363            0.006909
# 2018-05-07                   0.008047            0.002994
# 2018-05-08                  -0.003793           -0.010821
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-02                    -0.019454                0.000131  0.005558
# 2018-05-03                     0.008883                0.000822  0.008960
# 2018-05-04                     0.042637                0.008794  0.000648
# 2018-05-07                     0.010428                0.008954  0.006150
# 2018-05-08                    -0.001354               -0.000946 -0.001733
#
#               Algo 2  SP500 Close      AMZN       BLK      META
# 2018-05-02  0.001319    -0.007206 -0.007964 -0.006139  0.012711
# 2018-05-03 -0.002614    -0.002254  0.001529 -0.006061 -0.011643
# 2018-05-04  0.008404     0.012811  0.005725  0.017062  0.014883
# 2018-05-07  0.003798     0.003458  0.012144  0.006149  0.007701
# 2018-05-08  0.001310    -0.000266 -0.004874 -0.007009  0.005338

# %%
# Calculate the annualized `std`
annualized_std = myport.std() * np.sqrt(252)

# %%
# Calculate rolling standard deviation
rolling_std_21 = myport.rolling(window=21).std()
# Plot rolling standard deviation
rolling_std_21.plot(title="21-Day Rolling Standard Deviation")
# Out:
# <Axes: title={'center': '21-Day Rolling Standard Deviation'}>

# %%
# Calculate and plot the correlation
correlation = myport.corr()
correlation.plot(kind='bar', title='Correlation Matrix')
# Out:
# <Axes: title={'center': 'Correlation Matrix'}>

# %%
# Calculate and plot Beta
rolling_covariance = myport.rolling(window=60).cov(sp500_returns)
rolling_variance = sp500_returns.rolling(window=60).var()
rolling_beta_60 = rolling_variance / rolling_covariance
rolling_beta_60.plot(title='Rolling 60-Day Beta of My Portfolio')
# Out:
# <Axes: title={'center': 'Rolling 60-Day Beta of My Portfolio'}>

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios = column_appended_data.mean() / column_appended_data.std()
sharpe_ratios_annualized = sharpe_ratios * np.sqrt(252)

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_annualized.plot(kind= 'bar', title='Annualized Sharpe Ratios')
# Out:
# <Axes: title={'center': 'Annualized Sharpe Ratios'}>
